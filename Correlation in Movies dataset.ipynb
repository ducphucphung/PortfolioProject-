# %%
#Import the needed library
import pandas as pd
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
plt.style.use('ggplot')

# %%
#read in data
fd = pd.read_csv('C:\\Users\\DUC PHUC\\Desktop\\Data Analytics Portfolio Project\\Project_4\\movies.csv')

# %%
#Dealing with null values
fd.isnull().sum()
fd=fd.dropna()

# %%
fd.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#Convert types of the following columns into int
fd['votes']=fd['votes'].astype('int64')
fd['budget']=fd['budget'].astype('int64')
fd['gross']=fd['gross'].astype('int64')

# %%
fd
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score    votes  \
# ...

# %%
fd.dtypess
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes         int64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
#Get the correct released year
fd['yearcorrect'] = fd['released'].str.extract(pat = '([0-9]{4})').astype(int)

# %%
fd.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score    votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000     Stanley Kubrick
# ...

# %%
#Allow user to see all the rows in the table
pd.set_option('display.max_rows', None)

# %%
#Sort values by column gross
fd = fd.sort_values(by=['gross'], inplace=False, ascending=False)

# %%
#Drop duplicated rows
fd = fd.drop_duplicates().describe()
# Out:
#               year        score         votes        budget         gross  \
# count  5421.000000  5421.000000  5.421000e+03  5.421000e+03  5.421000e+03
# mean   2001.661317     6.392455  1.150661e+05  3.600917e+07  1.032297e+08
# std      10.540908     0.962730  1.844073e+05  4.157337e+07  1.873027e+08
# min    1980.000000     1.900000  1.950000e+02  6.000000e+03  3.090000e+02
# 25%    1993.000000     5.800000  1.900000e+04  1.000000e+07  1.073640e+07
# 50%    2002.000000     6.500000  5.200000e+04  2.180000e+07  3.686941e+07
# 75%    2011.000000     7.100000  1.290000e+05  4.500000e+07  1.124625e+08
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime  yearcorrect
# count  5421.000000  5421.000000
# mean    108.152739  2001.814794
# std      18.115698    10.550774
# min      63.000000  1980.000000
# 25%      95.000000  1993.000000
# 50%     105.000000  2002.000000
# 75%     118.000000  2011.000000
# max     271.000000  2020.000000

# %%
pd.value_counts(fd.duplicated())
# Out:
# False    5421
# Name: count, dtype: int64

# %%
film_data = pd.read_csv('C:\\Users\\DUC PHUC\\Desktop\\Data Analytics Portfolio Project\\Project_4\\movies.csv')
film_data.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  7668.000000  7665.000000  7.665000e+03  5.497000e+03  7.479000e+03
# mean   2000.405451     6.390411  8.810850e+04  3.558988e+07  7.850054e+07
# std      11.153508     0.968842  1.633238e+05  4.145730e+07  1.657251e+08
# min    1980.000000     1.900000  7.000000e+00  3.000000e+03  3.090000e+02
# 25%    1991.000000     5.800000  9.100000e+03  1.000000e+07  4.532056e+06
# 50%    2000.000000     6.500000  3.300000e+04  2.050000e+07  2.020576e+07
# 75%    2010.000000     7.100000  9.300000e+04  4.500000e+07  7.601669e+07
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime
# count  7664.000000
# mean    107.261613
# std      18.581247
# min      55.000000
# 25%      95.000000
# 50%     104.000000
# 75%     116.000000
# max     366.000000

# %%
film_data.duplicated(film_data)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
# 30      False
# 31      False
# 32      False
# 33      False
# 34      False
# 35      False
# 36      False
# 37      False
# 38      False
# 39      False
# 40      False
# 41      False
# 42      False
# 43      False
# 44      False
# 45      False
# 46      False
# 47      False
# 48      False
# 49      False
# 50      False
# 51      False
# 52      False
# 53      False
# 54      False
# 55      False
# 56      False
# 57      False
# 58      False
# 59      False
# 60      False
# 61      False
# ...

# %%
pd.value_counts(film_data.duplicated())
# Out:
# False    7668
# Name: count, dtype: int64

# %%
#
(fd.dtypes!='int64') & (fd.dtypes!='float64')
# Out:
# name            True
# rating          True
# genre           True
# year           False
# released        True
# score          False
# votes          False
# director        True
# writer          True
# star            True
# country         True
# budget         False
# gross          False
# company         True
# runtime        False
# yearcorrect     True
# dtype: bool

# %%
fd.dtypes
# Out:
# name            object
# rating          object
# genre           object
# year             int64
# released        object
# score          float64
# votes            int64
# director        object
# writer          object
# star            object
# country         object
# budget           int64
# gross            int64
# company         object
# runtime        float64
# yearcorrect      int32
# dtype: object

# %%
#Drop all categorical columns
drop_data = fd.drop(['name', 'rating', 'genre', 'released', 'director', 'writer', 'star', 'country', 'company', 'year'], axis=1)
correlation_matrix=sns.heatmap(drop_data.corr(), annot=True, cmap='Reds')

plt.title("Correlation maxtrix for 'movies' dataset'")
# Out:
# Text(0.5, 1.0, "Correlation maxtrix for 'movies' dataset'")

# %%
regression_matrix=sns.regplot(x='budget', y='gross', data=drop_data, line_kws={'color': 'blue'})
plt.title('Regression model between gross and budget', font)
# Out:
# Text(0.5, 1.0, 'Regression model between gross and budget')

# %%
correlation_pair = drop_data.corr().unstack().sort_values(ascending=False)
correlation_pair.astype('float')
# Out:
# score        score          1.000000
# votes        votes          1.000000
# runtime      runtime        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# yearcorrect  yearcorrect    1.000000
# gross        budget         0.740247
# budget       gross          0.740247
# votes        gross          0.614751
# gross        votes          0.614751
# votes        score          0.474256
# score        votes          0.474256
# votes        budget         0.439675
# budget       votes          0.439675
# runtime      score          0.414068
# score        runtime        0.414068
# runtime      votes          0.352303
# votes        runtime        0.352303
# budget       yearcorrect    0.320312
# yearcorrect  budget         0.320312
# runtime      budget         0.318695
# budget       runtime        0.318695
# runtime      gross          0.275796
# gross        runtime        0.275796
# yearcorrect  gross          0.268721
# ...

# %%
correlation_pair=correlation_pair[correlation_pair>0.5].drop_duplicates()
correlation_pair=correlation_pair[correlation_pair<1].drop_duplicates()
correlation_pair
# Out:
# gross  budget    0.740247
# votes  gross     0.614751
# dtype: float64

# %%
# Out:
#                      0
# score score   1.000000
# gross budget  0.740247
# votes gross   0.614751
